# %% [markdown]
# # A simple analysis using the plot-likert module

# %%
from IPython.display import display, Markdown, Latex # Print markdown in jupyter
import os
import pandas as pd # Dataframes
import plot_likert # Likert scale analysis

# %% [markdown]
# ### 1. Import dataset

# %%
datadir = 'data/' # add this directory in your system and store your csv data there.
table = 'scores_M.csv' # the name of my dataset. Change it to fit yours.

# Read data into a pandas dataframe
df = pd.read_csv(os.path.join(datadir, table), sep= '\t') # my data is actually a tab-separated table

if not df.empty:
    display(Markdown(f"""_Your file `{table}` is loaded_"""))
    # Look at the description of your dataset
    df.info()
else:
    print(f"""Your dataset was not loaded""")
# Out:
# _Your file `scores_M.csv` is loaded_
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Participant  319 non-null    object
#  1   Question     319 non-null    object
#  2   Response     319 non-null    object
#  3   Number       319 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 10.1+ KB

# %% [markdown]
# #### Get some key descriptions of the dataset

# %%
# Get length of the dataset
df_len = len(df['Participant'])
# Get number of unique questions
questions_n = len(df['Question'].unique())
# Get number of unique participants
participants_n = len(df['Participant'].unique())
# Compensate for the difference between zero indexing and early stop in range function later
zero_range_diff = 2
range_top = df_len + zero_range_diff - participants_n

display(Markdown(f"""_Your dataset contains {questions_n} responses for each of the {participants_n} participants in my data.
Responses are stacked on top of each other so a new participant is shown every {questions_n} rows.
Here are all the columns and the top {questions_n * 2 + 1} rows_"""))
df.head(questions_n * 2 + 1)
# Out:
# _Your dataset contains 11 responses for each of the 29 participants in my data.
# Responses are stacked on top of each other so a new participant is shown every 11 rows.
# Here are all the columns and the top 23 rows_
#    Participant Question Response  Number
# 0           P1       Q1        A       5
# 1           P1       Q2        A       5
# 2           P1       Q3        A       5
# 3           P1       Q4        D       3
# 4           P1       Q5        N       4
# 5           P1       Q6        A       5
# 6           P1       Q7        A       5
# 7           P1       Q8        A       5
# 8           P1       Q9        A       5
# 9           P1      Q10        A       5
# 10          P1      Q11        A       5
# 11          P2       Q1        A       5
# 12          P2       Q2       SA       6
# 13          P2       Q3       SA       6
# 14          P2       Q4        A       5
# 15          P2       Q5       SA       6
# 16          P2       Q6        A       5
# 17          P2       Q7        A       5
# 18          P2       Q8       SA       6
# 19          P2       Q9        A       5
# 20          P2      Q10       SA       6
# 21          P2      Q11        A       5
# 22          P3       Q1        A       5

# %% [markdown]
# ### 2. Wrangle dataset
# The data must be in an `ID  Question1  Question2  QuestionN` format, so we must make it fit.

# %%
# There are no missing (NaN) values are contained in this dataset

# Get likert scores responses in a list of list with all 29 participants and 11 responses each
scores = [df.iloc[x:x+questions_n].Response.tolist() for x in range(0, range_top, questions_n)]

# The responses must be turned into a format that fits the scale in plot_likert (see https://github.com/nmalkin/plot-likert/blob/master/plot_likert/scales.py)
# In this case, the  responses have been abbreviated as "SA, A, N" etc. We will map the responses to a standard format.
scores5_0_dict = {
'SA': '5 - Strongly Agree',  
'A': '4 - Agree',
'N': '3 - Neither Agree nor Disagree',
'D': '2 - Disagree',
'SD': '1 - Strongly Disagree',
'NS': '0 - Not Sure'
}
scores = [[scores5_0_dict[x] for x in subl] for subl in scores]

# =============== IGNORE THIS BIT
# The numbers in scores must be turned into strings to fit the scale in plot_likert (see https://github.com/nmalkin/plot-likert/blob/master/plot_likert/scales.py)
# scores = [[str(x) for x in subl] for subl in scores]
# Get participant IDs
# parts = [df.iat[x,0] for x in range(0, 310, 11)]
# df2['participant'] = parts

# %%
# Create dataframe with the scores, then add the participant IDs
question_texts = [
'1. To feel good about myself',
'2. Because it helps me to make money at my job',
'3. Because I do not want to lose my language',
'4. Because I like to listen to Spanish programs on radio and TV',
'5. To give me more chances to express my feelings',
'6. Because it helps me to be more broadly educated',
'7. To keep my traditional values',
'8. Because it is a beautiful language',
'9. To complete part of my general education',
'10. To teach it to my children',
'11. To get along with my parents, relatives, and friends',
]
# df2 = pd.DataFrame(scores, columns = ['Q{}'.format(i) for i in range(1,12)])
df2 = pd.DataFrame(scores, columns = [i for i in question_texts])
# Look at the top 5 rows
df2.head(5)
# Out:
#   1. To feel good about myself 2. Because it helps me to make money at my job  \
# 0                    4 - Agree                                      4 - Agree
# 1                    4 - Agree                             5 - Strongly Agree
# 2                    4 - Agree                 3 - Neither Agree nor Disagree
# 3                 2 - Disagree                                      4 - Agree
# 4                    4 - Agree                                      4 - Agree
#
#   3. Because I do not want to lose my language  \
# 0                                    4 - Agree
# 1                           5 - Strongly Agree
# 2                                    4 - Agree
# 3                                    4 - Agree
# 4                                    4 - Agree
#
#   4. Because I like to listen to Spanish programs on radio and TV  \
# 0                                       2 - Disagree
# 1                                          4 - Agree
# 2                                          4 - Agree
# 3                     3 - Neither Agree nor Disagree
# 4                                          4 - Agree
#
#   5. To give me more chances to express my feelings  \
# 0                    3 - Neither Agree nor Disagree
# 1                                5 - Strongly Agree
# 2                    3 - Neither Agree nor Disagree
# 3                                      2 - Disagree
# 4                                         4 - Agree
#
#   6. Because it helps me to be more broadly educated  \
# 0                                          4 - Agree
# 1                                          4 - Agree
# 2                                          4 - Agree
# 3                                          4 - Agree
# 4                                          4 - Agree
#
#   7. To keep my traditional values 8. Because it is a beautiful language  \
# 0                        4 - Agree                             4 - Agree
# 1                        4 - Agree                    5 - Strongly Agree
# 2                        4 - Agree                             4 - Agree
# 3                     2 - Disagree                             4 - Agree
# 4                        4 - Agree                             4 - Agree
#
#   9. To complete part of my general education  10. To teach it to my children  \
# 0                                   4 - Agree                       4 - Agree
# 1                                   4 - Agree              5 - Strongly Agree
# 2                                   4 - Agree  3 - Neither Agree nor Disagree
# 3                                   4 - Agree                       4 - Agree
# 4                                   4 - Agree                       4 - Agree
#
#   11. To get along with my parents, relatives, and friends
# 0                                          4 - Agree
# 1                                          4 - Agree
# 2                     3 - Neither Agree nor Disagree
# 3                     3 - Neither Agree nor Disagree
# 4                                          4 - Agree

# %% [markdown]
# ### 3. Analysis

# %% [markdown]
# ##### 3.1 Raw counts

# %%
counts = plot_likert.likert_counts(df2, plot_likert.scales.scores5_0_custom)
counts
# Out:
#                                                     0 - Not Sure  \
# 1. To feel good about myself                                 0.0
# 2. Because it helps me to make\nmoney at my job              1.0
# 3. Because I do not want to\nlose my language                0.0
# 4. Because I like to listen to\nSpanish program...           0.0
# 5. To give me more chances to\nexpress my feelings           1.0
# 6. Because it helps me to be\nmore broadly educ...           0.0
# 7. To keep my traditional\nvalues                            0.0
# 8. Because it is a beautiful\nlanguage                       0.0
# 9. To complete part of my\ngeneral education                 0.0
# 10. To teach it to my children                               1.0
# 11. To get along with my\nparents, relatives, a...           1.0
#
#                                                     1 - Strongly Disagree  \
# 1. To feel good about myself                                          0.0
# 2. Because it helps me to make\nmoney at my job                       0.0
# 3. Because I do not want to\nlose my language                         0.0
# 4. Because I like to listen to\nSpanish program...                    1.0
# 5. To give me more chances to\nexpress my feelings                    1.0
# 6. Because it helps me to be\nmore broadly educ...                    0.0
# 7. To keep my traditional\nvalues                                     0.0
# 8. Because it is a beautiful\nlanguage                                0.0
# 9. To complete part of my\ngeneral education                          0.0
# 10. To teach it to my children                                        0.0
# 11. To get along with my\nparents, relatives, a...                    0.0
#
#                                                     2 - Disagree  \
# 1. To feel good about myself                                 2.0
# 2. Because it helps me to make\nmoney at my job              0.0
# 3. Because I do not want to\nlose my language                1.0
# 4. Because I like to listen to\nSpanish program...           7.0
# 5. To give me more chances to\nexpress my feelings           5.0
# 6. Because it helps me to be\nmore broadly educ...           0.0
# 7. To keep my traditional\nvalues                            2.0
# 8. Because it is a beautiful\nlanguage                       0.0
# 9. To complete part of my\ngeneral education                 2.0
# 10. To teach it to my children                               0.0
# 11. To get along with my\nparents, relatives, a...           1.0
#
#                                                     3 - Neither Agree nor Disagree  \
# 1. To feel good about myself                                                   1.0
# 2. Because it helps me to make\nmoney at my job                                4.0
# 3. Because I do not want to\nlose my language                                  2.0
# 4. Because I like to listen to\nSpanish program...                             4.0
# 5. To give me more chances to\nexpress my feelings                             4.0
# 6. Because it helps me to be\nmore broadly educ...                             0.0
# 7. To keep my traditional\nvalues                                              0.0
# 8. Because it is a beautiful\nlanguage                                         3.0
# 9. To complete part of my\ngeneral education                                   1.0
# 10. To teach it to my children                                                 2.0
# 11. To get along with my\nparents, relatives, a...                             3.0
#
#                                                     4 - Agree  \
# 1. To feel good about myself                             15.0
# 2. Because it helps me to make\nmoney at my job          12.0
# 3. Because I do not want to\nlose my language            11.0
# 4. Because I like to listen to\nSpanish program...       10.0
# 5. To give me more chances to\nexpress my feelings       10.0
# 6. Because it helps me to be\nmore broadly educ...       11.0
# 7. To keep my traditional\nvalues                        15.0
# 8. Because it is a beautiful\nlanguage                   11.0
# 9. To complete part of my\ngeneral education             18.0
# 10. To teach it to my children                           10.0
# 11. To get along with my\nparents, relatives, a...       10.0
#
#                                                     5 - Strongly Agree
# 1. To feel good about myself                                       9.0
# 2. Because it helps me to make\nmoney at my job                   10.0
# 3. Because I do not want to\nlose my language                     13.0
# 4. Because I like to listen to\nSpanish program...                 5.0
# 5. To give me more chances to\nexpress my feelings                 6.0
# 6. Because it helps me to be\nmore broadly educ...                16.0
# 7. To keep my traditional\nvalues                                 10.0
# 8. Because it is a beautiful\nlanguage                            13.0
# 9. To complete part of my\ngeneral education                       6.0
# 10. To teach it to my children                                    14.0
# 11. To get along with my\nparents, relatives, a...                12.0

# %% [markdown]
# ##### 3.2 Percentages

# %%
percentages = plot_likert.likert_percentages(df2, plot_likert.scales.scores5_0_custom)
percentages
# Out:
#                                                     0 - Not Sure  \
# 1. To feel good about myself                            0.000000
# 2. Because it helps me to make\nmoney at my job         3.703704
# 3. Because I do not want to\nlose my language           0.000000
# 4. Because I like to listen to\nSpanish program...      0.000000
# 5. To give me more chances to\nexpress my feelings      3.703704
# 6. Because it helps me to be\nmore broadly educ...      0.000000
# 7. To keep my traditional\nvalues                       0.000000
# 8. Because it is a beautiful\nlanguage                  0.000000
# 9. To complete part of my\ngeneral education            0.000000
# 10. To teach it to my children                          3.703704
# 11. To get along with my\nparents, relatives, a...      3.703704
#
#                                                     1 - Strongly Disagree  \
# 1. To feel good about myself                                     0.000000
# 2. Because it helps me to make\nmoney at my job                  0.000000
# 3. Because I do not want to\nlose my language                    0.000000
# 4. Because I like to listen to\nSpanish program...               3.703704
# 5. To give me more chances to\nexpress my feelings               3.703704
# 6. Because it helps me to be\nmore broadly educ...               0.000000
# 7. To keep my traditional\nvalues                                0.000000
# 8. Because it is a beautiful\nlanguage                           0.000000
# 9. To complete part of my\ngeneral education                     0.000000
# 10. To teach it to my children                                   0.000000
# 11. To get along with my\nparents, relatives, a...               0.000000
#
#                                                     2 - Disagree  \
# 1. To feel good about myself                            7.407407
# 2. Because it helps me to make\nmoney at my job         0.000000
# 3. Because I do not want to\nlose my language           3.703704
# 4. Because I like to listen to\nSpanish program...     25.925926
# 5. To give me more chances to\nexpress my feelings     18.518519
# 6. Because it helps me to be\nmore broadly educ...      0.000000
# 7. To keep my traditional\nvalues                       7.407407
# 8. Because it is a beautiful\nlanguage                  0.000000
# 9. To complete part of my\ngeneral education            7.407407
# 10. To teach it to my children                          0.000000
# 11. To get along with my\nparents, relatives, a...      3.703704
#
#                                                     3 - Neither Agree nor Disagree  \
# 1. To feel good about myself                                              3.703704
# 2. Because it helps me to make\nmoney at my job                          14.814815
# 3. Because I do not want to\nlose my language                             7.407407
# 4. Because I like to listen to\nSpanish program...                       14.814815
# 5. To give me more chances to\nexpress my feelings                       14.814815
# 6. Because it helps me to be\nmore broadly educ...                        0.000000
# 7. To keep my traditional\nvalues                                         0.000000
# 8. Because it is a beautiful\nlanguage                                   11.111111
# 9. To complete part of my\ngeneral education                              3.703704
# 10. To teach it to my children                                            7.407407
# 11. To get along with my\nparents, relatives, a...                       11.111111
#
#                                                     4 - Agree  \
# 1. To feel good about myself                        55.555556
# 2. Because it helps me to make\nmoney at my job     44.444444
# 3. Because I do not want to\nlose my language       40.740741
# 4. Because I like to listen to\nSpanish program...  37.037037
# 5. To give me more chances to\nexpress my feelings  37.037037
# 6. Because it helps me to be\nmore broadly educ...  40.740741
# 7. To keep my traditional\nvalues                   55.555556
# 8. Because it is a beautiful\nlanguage              40.740741
# 9. To complete part of my\ngeneral education        66.666667
# 10. To teach it to my children                      37.037037
# 11. To get along with my\nparents, relatives, a...  37.037037
#
#                                                     5 - Strongly Agree
# 1. To feel good about myself                                 33.333333
# 2. Because it helps me to make\nmoney at my job              37.037037
# 3. Because I do not want to\nlose my language                48.148148
# 4. Because I like to listen to\nSpanish program...           18.518519
# 5. To give me more chances to\nexpress my feelings           22.222222
# 6. Because it helps me to be\nmore broadly educ...           59.259259
# 7. To keep my traditional\nvalues                            37.037037
# 8. Because it is a beautiful\nlanguage                       48.148148
# 9. To complete part of my\ngeneral education                 22.222222
# 10. To teach it to my children                               51.851852
# 11. To get along with my\nparents, relatives, a...           44.444444

# %% [markdown]
# ### 4. Plot

# %%
# Customize colors
likert_colors = ['white','green', 'firebrick','lightcoral','gainsboro','cornflowerblue', 'darkblue']

# %%
plot_likert.plot_counts(percentages, plot_likert.scales.scores5_0_custom, plot_percentage=True, colors=likert_colors, figsize=[10,6], title="Survey - Maintenance")
